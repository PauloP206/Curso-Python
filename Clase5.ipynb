# %% [markdown]
# <a href="https://colab.research.google.com/github/PauloP206/Curso-Python/blob/main/Clase5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *visualizaciones*
#
# Curso Pytone
#
# Unicafam
#
# Estudiante: Paulo Castellanos
#
# Docente: Nicolas Mojica

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
#cargar un data filr atraves de la libreria pandas

comparacion_ventas_exp=pd.read_csv('/content/sample_data/comparacion_ventas_exp.csv')

comparacion_ventas_exp
# Out:
#          Fecha Región Producto  Ventas
# 0   2024-01-01  Norte        A   12000
# 1   2024-01-01    Sur        B   15000
# 2   2024-02-01   Este        A   18000
# 3   2024-03-01    Sur        C   11000
# 4   2024-01-01  Norte        A   12000
# ..         ...    ...      ...     ...
# 95  2024-03-01  Norte        B   16000
# 96  2024-02-01   Este        A   18000
# 97  2024-01-01  Norte        A   12000
# 98  2024-03-01    Sur        C   11000
# 99  2024-02-01   Este        A   18000
#
# [100 rows x 4 columns]

# %%
composicion_mercado_exp=pd.read_csv('/content/composicion_mercado_exp.csv')

composicion_mercado_exp
# Out:
#    Empresa Producto  Participación (%) Trimestre
# 0   X Corp        A                 20   Q1 2024
# 1   Y Corp        B                 30   Q1 2024
# 2    Z Inc        A                 15   Q1 2024
# 3    Z Inc        B                 20   Q2 2024
# 4   X Corp        A                 20   Q1 2024
# ..     ...      ...                ...       ...
# 95  Y Corp        A                 10   Q2 2024
# 96   Z Inc        A                 15   Q1 2024
# 97  X Corp        A                 20   Q1 2024
# 98   Z Inc        B                 20   Q2 2024
# 99   Z Inc        A                 15   Q1 2024
#
# [100 rows x 4 columns]

# %%
correlacion_marketing_exp=pd.read_csv('/content/correlacion_marketing_exp.csv')

correlacion_marketing_exp
# Out:
#     Campaña ID  Inversión en marketing (USD)  Ventas generadas (USD)  \
# 0            1                          5000                   25000
# 1            2                         10000                   60000
# 2            3                          7500                   40000
# 3            6                          6000                   30000
# 4            1                          5000                   25000
# ..         ...                           ...                     ...
# 95           5                          8000                   45000
# 96           3                          7500                   40000
# 97           1                          5000                   25000
# 98           6                          6000                   30000
# 99           3                          7500                   40000
#
#    Fecha de la campaña
# 0           2024-01-15
# 1           2024-02-20
# 2           2024-03-10
# 3           2024-06-15
# ...

# %%
distribucion_tiempos_exp=pd.read_csv('/content/distribucion_tiempos_exp.csv')

distribucion_tiempos_exp
# Out:
#     Ticket ID Fecha de creación  Tiempo de respuesta (horas)
# 0           1        2024-07-01                          2.5
# 1           2        2024-07-01                          1.0
# 2           3        2024-07-02                          4.5
# 3           6        2024-07-03                          1.5
# 4           1        2024-07-01                          2.5
# ..        ...               ...                          ...
# 95          5        2024-07-03                          3.0
# 96          3        2024-07-02                          4.5
# 97          1        2024-07-01                          2.5
# 98          6        2024-07-03                          1.5
# 99          3        2024-07-02                          4.5
#
# [100 rows x 3 columns]

# %% [markdown]
# *graficas de correlacion*

# %%
correlacion_marketing_exp.head(5)
# Out:
#    Campaña ID  Inversión en marketing (USD)  Ventas generadas (USD)  \
# 0           1                          5000                   25000
# 1           2                         10000                   60000
# 2           3                          7500                   40000
# 3           6                          6000                   30000
# 4           1                          5000                   25000
#
#   Fecha de la campaña
# 0          2024-01-15
# 1          2024-02-20
# 2          2024-03-10
# 3          2024-06-15
# 4          2024-01-15

# %%
# grafica de correlacion de la inversion vs las ventas ingresadas

#df = sns.load_dataset('correlacion_marketing_exp')

sns.scatterplot(x=correlacion_marketing_exp['Inversión en marketing (USD)'], y=correlacion_marketing_exp['Ventas generadas (USD)'])
# Out:
# <Axes: xlabel='Inversión en marketing (USD)', ylabel='Ventas generadas (USD)'>

# %%
sns.scatterplot(x=correlacion_marketing_exp['Inversión en marketing (USD)'], y=correlacion_marketing_exp['Ventas generadas (USD)'],color='red')
# Out:
# <Axes: xlabel='Inversión en marketing (USD)', ylabel='Ventas generadas (USD)'>

# %%
#style='species'
#color='black'

sns.scatterplot(x=correlacion_marketing_exp['Inversión en marketing (USD)'], y=correlacion_marketing_exp['Ventas generadas (USD)'],hue=correlacion_marketing_exp['Campaña ID'],legend=True)
# Out:
# <Axes: xlabel='Inversión en marketing (USD)', ylabel='Ventas generadas (USD)'>

# %% [markdown]
# **[texto del vínculo](https://)

# %%
#grafica de calor heatmap

sns.heatmap(correlacion_marketing_exp[['Campaña ID','Inversión en marketing (USD)','Ventas generadas (USD)']])
# Out:
# <Axes: >

# %%
comparacion_ventas_exp.head(5)
# Out:
#         Fecha Región Producto  Ventas
# 0  2024-01-01  Norte        A   12000
# 1  2024-01-01    Sur        B   15000
# 2  2024-02-01   Este        A   18000
# 3  2024-03-01    Sur        C   11000
# 4  2024-01-01  Norte        A   12000

# %%
# comparacion
comparacion_ventas_exp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Fecha     100 non-null    object
#  1   Región    100 non-null    object
#  2   Producto  100 non-null    object
#  3   Ventas    100 non-null    int64
# dtypes: int64(1), object(3)
# memory usage: 3.2+ KB

# %%
#graficas de comparacion
# nombre de los ejes

x=pd.to_datetime(comparacion_ventas_exp['Fecha'])
y=comparacion_ventas_exp['Ventas']
fig,ax=plt.subplots()
ax.plot(x,y)
plt.show()

# %%
# grafica de composicion

composicion_mercado_exp.head(5)

# filtrar que lso datos sean Q1 2024
# Out:
#   Empresa Producto  Participación (%) Trimestre
# 0  X Corp        A                 20   Q1 2024
# 1  Y Corp        B                 30   Q1 2024
# 2   Z Inc        A                 15   Q1 2024
# 3   Z Inc        B                 20   Q2 2024
# 4  X Corp        A                 20   Q1 2024

# %%
# filtrar que lso datos sean Q1 2024

grafica_composicion=composicion_mercado_exp[composicion_mercado_exp['Trimestre']=='Q1 2024']

grafica_composicion1=grafica_composicion[composicion_mercado_exp['Empresa']=='X Corp']

grafica_composicion1
# Out:
# <ipython-input-54-d648f84dd0b7>:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   grafica_composicion1=grafica_composicion[composicion_mercado_exp['Empresa']=='X Corp']
#    Empresa Producto  Participación (%) Trimestre
# 0   X Corp        A                 20   Q1 2024
# 4   X Corp        A                 20   Q1 2024
# 6   X Corp        A                 20   Q1 2024
# 9   X Corp        A                 20   Q1 2024
# 10  X Corp        A                 20   Q1 2024
# 18  X Corp        A                 20   Q1 2024
# 30  X Corp        A                 20   Q1 2024
# 37  X Corp        A                 20   Q1 2024
# 45  X Corp        A                 20   Q1 2024
# 53  X Corp        A                 20   Q1 2024
# 59  X Corp        A                 20   Q1 2024
# 60  X Corp        A                 20   Q1 2024
# 61  X Corp        A                 20   Q1 2024
# 65  X Corp        A                 20   Q1 2024
# ...

# %%
grafica_composicion = composicion_mercado_exp[
    (composicion_mercado_exp['Trimestre'] == "Q1 2024") &
    (composicion_mercado_exp['Empresa'] == "X Corp")
]

grafica_composicion
# Out:
#    Empresa Producto  Participación (%) Trimestre
# 0   X Corp        A                 20   Q1 2024
# 4   X Corp        A                 20   Q1 2024
# 6   X Corp        A                 20   Q1 2024
# 9   X Corp        A                 20   Q1 2024
# 10  X Corp        A                 20   Q1 2024
# 18  X Corp        A                 20   Q1 2024
# 30  X Corp        A                 20   Q1 2024
# 37  X Corp        A                 20   Q1 2024
# 45  X Corp        A                 20   Q1 2024
# 53  X Corp        A                 20   Q1 2024
# 59  X Corp        A                 20   Q1 2024
# 60  X Corp        A                 20   Q1 2024
# 61  X Corp        A                 20   Q1 2024
# 65  X Corp        A                 20   Q1 2024
# 75  X Corp        A                 20   Q1 2024
# 80  X Corp        A                 20   Q1 2024
# 97  X Corp        A                 20   Q1 2024

# %%
# creae una lista

tamano_grupos=[12,11,3,30]
#creacion de la grafica
plt.pie(tamano_grupos)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
distribucion_tiempos_exp
# Out:
#     Ticket ID Fecha de creación  Tiempo de respuesta (horas)
# 0           1        2024-07-01                          2.5
# 1           2        2024-07-01                          1.0
# 2           3        2024-07-02                          4.5
# 3           6        2024-07-03                          1.5
# 4           1        2024-07-01                          2.5
# ..        ...               ...                          ...
# 95          5        2024-07-03                          3.0
# 96          3        2024-07-02                          4.5
# 97          1        2024-07-01                          2.5
# 98          6        2024-07-03                          1.5
# 99          3        2024-07-02                          4.5
#
# [100 rows x 3 columns]

# %%
# grafica de distribucion

sns.boxplot(x=distribucion_tiempos_exp['Fecha de creación'],y=distribucion_tiempos_exp['Tiempo de respuesta (horas)'])
# Out:
# <Axes: xlabel='Fecha de creación', ylabel='Tiempo de respuesta (horas)'>

# %%
correlacion_marketing_exp
# Out:
#     Campaña ID  Inversión en marketing (USD)  Ventas generadas (USD)  \
# 0            1                          5000                   25000
# 1            2                         10000                   60000
# 2            3                          7500                   40000
# 3            6                          6000                   30000
# 4            1                          5000                   25000
# ..         ...                           ...                     ...
# 95           5                          8000                   45000
# 96           3                          7500                   40000
# 97           1                          5000                   25000
# 98           6                          6000                   30000
# 99           3                          7500                   40000
#
#    Fecha de la campaña
# 0           2024-01-15
# 1           2024-02-20
# 2           2024-03-10
# 3           2024-06-15
# ...

# %%
df = sns.load_dataset(correlacion_marketing_exp)

# Make default density plot
sns.kdeplot(df['Inversión en marketing (USD)'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-2c663d115c6d> in <cell line: 4>()
#       2
#       3 # Make default density plot
# ----> 4 sns.kdeplot(df['Inversión en marketing (USD)'])
#
# NameError: name 'df' is not defined
